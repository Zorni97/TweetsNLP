# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import pickle
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np

# %%
#Importamos los datos
with open('files/tokenized_documents.pkl', 'rb') as f:
    tokenized_documents = pickle.load(f)
with open('files/lemmatized_documents.pkl', 'rb') as f:
    lemmatized_documents = pickle.load(f)
with open('files/feature_names.pkl', 'rb') as f:
    feature_names = pickle.load(f)

# %%
no_features = 1000

# tf-idf para NMF, ya que es un modelo matemático basado en algebra lineal.
# Se aplica un Preprocessor que una las palabras de cada documento antes de hacer la matriz tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, preprocessor=' '.join,
                                   max_features=no_features, stop_words='english', lowercase=False)
tfidf = tfidf_vectorizer.fit_transform(lemmatized_documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# # tf para LDA porque es un modelo probabilístico.
# # Se aplica el mismo preprocessor que en tf-idf, ya que tenemos los documentos tokenizados
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, preprocessor=' '.join, lowercase=False,
                                 max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(lemmatized_documents)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
#Importamos los modelos pre-entrenados

with open('files/nmf.pkl', 'rb') as f:
    nmf = pickle.load(f)

with open('files/lda.pkl', 'rb') as f:
    lda = pickle.load(f)

# %%
# Creamos una función para mostrar los topics que ha creado cada modelo
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
no_top_words = 10
print("NMF topics:\n")
display_topics(nmf, tfidf_feature_names, no_top_words)
print("\nLDA topics:\n")
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# NMF topics:
#
# Topic 0:
# like said people dont time think make way good know
# Topic 1:
# said united government states officials military state islamic american china
# Topic 2:
# game games team players season points scored coach teams goal
# Topic 3:
# percent company billion million companies investors business market said year
# Topic 4:
# trump republican trumps mr campaign republicans donald presidential nominee voters
# Topic 5:
# graduated dr father university married mother york couple daughter received
# Topic 6:
# mr said party president redstone interview political office campaign executive
# Topic 7:
# ms said women woman mother shes family husband female children
# Topic 8:
# european union britain british europe vote london leave party economic
# Topic 9:
# art new museum york street city building artists space park
# Topic 10:
# court judge justice case law federal supreme prosecutors lawyers trial
# Topic 11:
# police said officers officer shooting department gun killed people city
# Topic 12:
# yankees mets season runs hit game said run home manager
# Topic 13:
# students school schools education college student university high said percent
# Topic 14:
# clinton mrs sanders clintons democratic campaign voters hillary primary obama
#
# LDA topics:
#
# Topic 0:
# percent million company said year billion oil companies business chief
# Topic 1:
# new city york art street said building park museum water
# Topic 2:
# said united states government american officials state military president china
# Topic 3:
# said season team players game league games yankees teams hit
# Topic 4:
# game said series points scored second win play goal games
# Topic 5:
# like new people time dont way think make good work
# Topic 6:
# said company companies like new facebook media people technology online
# Topic 7:
# trump mr clinton campaign republican mrs voters sanders democratic senator
# Topic 8:
# ms said school students family children mother father university life
# Topic 9:
# mr said president house obama interview people time like years
# Topic 10:
# court law case justice federal judge legal state states lawyer
# Topic 11:
# percent money year workers people financial years economy economic bank
# Topic 12:
# said dr health new women university medical article public report
# Topic 13:
# european union europe party british london french britain france paris
# Topic 14:
# said mr police people officers officer city death killed told

# %%
# Log Likelyhood: cuanto más mejor
print("Log Likelihood: ", lda.score(tf))
# Perplexity: cuanto más bajo mejor. Perplexity = exp(-1. * log-likelihood por palabra)
print("Perplexity: ", lda.perplexity(tf))
# Parámetros del modelo
print(lda.get_params())
# Out:
# Log Likelihood:  -9959773.95389847
# Perplexity:  494.94090095110624
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.5, 'learning_method': 'online', 'learning_offset': 50.0, 'max_doc_update_iter': 100, 'max_iter': 5, 'mean_change_tol': 0.001, 'n_components': 15, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': 0, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %%
# # Grid Search de metaparámetros LDA
search_params = {'n_components': [10, 15, 20, 25, 30], 'learning_decay': [.5, .7, .9]}
# # Iniciar modelo
lda = LatentDirichletAllocation(max_iter=5, learning_method='online', learning_offset=50.,random_state=0)
# # Iniciar clase Grid Search
model = GridSearchCV(lda, param_grid=search_params, verbose=2, n_jobs=5)
# # Entrenar Grid
model.fit(tf)

# %%
# # Mejor modelo
best_lda_model = model.best_estimator_
# # Mejor parametros
print("Best Model's Params: ", model.best_params_)
# # Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)
# # Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(tf))

# %%
# Crear matriz de temas para LDA
lda_output = lda.transform(tf)
# Nombres de columnas
topicnames = ["Topic" + str(i) for i in range(lda.n_components)]
# Índices de documentos
docnames = ["Doc" + str(i) for i in range(len(tokenized_documents))]
# Crear pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Coger el tema dominante por documento y crear una columna para el mismo
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic
# Estilizamos los valores en verde para ver mejor los temas dominantes
def color_green(val):
 color = 'green' if val > .1 else 'black'
 return 'color: {col}'.format(col=color)
def make_bold(val):
 weight = 700 if val > .1 else 400
 return 'font-weight: {weight}'.format(weight=weight)
# aplicamos los estilos
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col12 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col14 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row0_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col6 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col9 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col12 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col14 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row1_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col9 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col12 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col14 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row2_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col6 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col9 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col12 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col14 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row3_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_051426ca_95c2_11ea_81ca_7cb27d5073d6row4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_051426ca_95c2

# %%
# Hacemos lo mismo para el modelo NMF
nmf_output = nmf.transform(tfidf)
# Nombres de columnas
topicnames = ["Topic" + str(i) for i in range(nmf.n_components)]
# Índices de documentos
docnames = ["Doc" + str(i) for i in range(len(tokenized_documents))]
# Crear pandas dataframe
df_document_topic = pd.DataFrame(np.round(nmf_output, 2), columns=topicnames, index=docnames)
# Coger el tema dominante por documento y crear una columna para el mismo
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic
# Estilizamos los valores en verde para ver mejor los temas dominantes
def color_green(val):
 color = 'green' if val > .1 else 'black'
 return 'color: {col}'.format(col=color)
def make_bold(val):
 weight = 700 if val > .1 else 400
 return 'font-weight: {weight}'.format(weight=weight)
# aplicamos los estilos
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col12 {
#             color:  green;
#             font-weight:  700;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col14 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row0_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col12 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col14 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row1_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col12 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col14 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row2_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col11 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col12 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col13 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col14 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row3_col15 {
#             color:  green;
#             font-weight:  700;
#         }    #T_401fc4d4_95c2_11ea_b9ff_7cb27d5073d6row4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_401fc4d4_95c2

# %%
# Matriz Tema-palabra
df_topic_keywords = pd.DataFrame(lda.components_)
# Asignamos nombres a las columnas con las features y a las filas con los topics
df_topic_keywords.columns = feature_names
df_topic_keywords.index = topicnames
# mostramos los 5 primeros
df_topic_keywords.head()
# Out:
#            _____    ability        able      access   according    account  \
# Topic0  0.066667  43.783200   44.707071    0.710417  595.133110   1.523547
# Topic1  0.066667   0.066667   23.951247   70.167332  284.912952   0.066667
# Topic2  0.066667  86.892114  104.262491  173.864847  470.587083  69.746967
# Topic3  0.066667  75.815524  258.494466    0.066667   79.660457   6.093660
# Topic4  0.066667  45.052703   87.024193    0.066667    0.066667   0.066667
#
#            accused        act      action   actually  ...   written  \
# Topic0    0.066667   1.084235   26.136708   0.442474  ...  0.066729
# Topic1    0.066667   0.066667    0.066667   0.070462  ...  0.066667
# Topic2  169.743930  26.923575  152.803800   0.066667  ...  6.760440
# Topic3    0.066670  13.761367   20.448813  34.190499  ...  0.066667
# Topic4    0.066667   0.103850   12.323469   3.281715  ...  0.066667
#
#             wrong      wrote      yankees         year     yearold  \
# Topic0   0.066691   2.012129     0.066667  2139.470914    0.066667
# Topic1   0.066667   0.067607     0.066667   708.919959   61.558550
# Topic2   0.066667  84.682779     0.066667   698.205056   31.354826
# Topic3  41.361981   3.472349  1287.805822   960.694958   88.597406
# Topic4   8.555874   0.066667     0.066667   498.875335  162.406291
#
#               years         york       young       youre
# Topic0   524.001906   341.838900    0.066727    1.640066
# Topic1  1034.747961  3076.258527   49.220272    0.066667
# Topic2   695.381747     6.555391   56.171568    0.066667
# Topic3   698.647649    67.127182  222.680753  158.262106
# Topic4   347.670248     0.066667   11.031696   17.411010
#
# [5 rows x 1000 columns]

# %%
def show_topics(vectorizer, lda_model, n_words):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords
        
topic_keywords = show_topics(tf_vectorizer, lda, 10)
        
# Palabras más representativas de cada topic

df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#             Word 0   Word 1     Word 2      Word 3      Word 4      Word 5  \
# Topic 0    percent  million    company        said        year     billion
# Topic 1        new     city       york         art      street        said
# Topic 2       said   united     states  government    american   officials
# Topic 3       said   season       team     players        game      league
# Topic 4       game     said     series      points      scored      second
# Topic 5       like      new     people        time        dont         way
# Topic 6       said  company  companies        like         new    facebook
# Topic 7      trump       mr    clinton    campaign  republican         mrs
# Topic 8         ms     said     school    students      family    children
# Topic 9         mr     said  president       house       obama   interview
# Topic 10     court      law       case     justice     federal       judge
# Topic 11   percent    money       year     workers      people   financial
# Topic 12      said       dr     health         new       women  university
# Topic 13  european    union     europe       party     british      london
# Topic 14      said       mr     police      people    officers     officer
#
#             Word 6     Word 7      Word 8   Word 9
# Topic 0        oil  companies    business    chief
# Topic 1   building       park      museum    water
# Topic 2      state   military   president    china
# Topic 3      games    yankees       teams      hit
# Topic 4        win       play        goal    games
# Topic 5      think       make        good     work
# Topic 6      media     people  technology   online
# Topic 7     voters    sanders  democratic  senator
# Topic 8     mother     father  university     life
# Topic 9     people       time        like    years
# Topic 10     legal      state      states   lawyer
# Topic 11     years    economy    economic     bank
# Topic 12   medical    article      public   report
# Topic 13    french    britain      france    paris
# Topic 14      city      death      killed     told

# %%
# Creamos una columna con el nombre que asignamos a cada topic en función de sus palabras

Topics = ["Empresas","Ciudades","Gobierno","Deportes","Deportes", 
          "Otros", "Empresas Tech", "Política", "Familia", 
          "Presidente", "Ley", "Economía", "Salud", "Europa", "Policía"]
df_topic_keywords["Topics"] = Topics

# Subimos el fichero, ya que lo utiliza la clase principal de nuestro programa para asignar topics
with open('files/df_topic_keywords.pkl', 'wb') as f:
    pickle.dump(df_topic_keywords, f)
df_topic_keywords
# Out:
#             Word 0   Word 1     Word 2      Word 3      Word 4      Word 5  \
# Topic 0    percent  million    company        said        year     billion
# Topic 1        new     city       york         art      street        said
# Topic 2       said   united     states  government    american   officials
# Topic 3       said   season       team     players        game      league
# Topic 4       game     said     series      points      scored      second
# Topic 5       like      new     people        time        dont         way
# Topic 6       said  company  companies        like         new    facebook
# Topic 7      trump       mr    clinton    campaign  republican         mrs
# Topic 8         ms     said     school    students      family    children
# Topic 9         mr     said  president       house       obama   interview
# Topic 10     court      law       case     justice     federal       judge
# Topic 11   percent    money       year     workers      people   financial
# Topic 12      said       dr     health         new       women  university
# Topic 13  european    union     europe       party     british      london
# Topic 14      said       mr     police      people    officers     officer
#
#             Word 6     Word 7      Word 8   Word 9         Topics
# Topic 0        oil  companies    business    chief       Empresas
# Topic 1   building       park      museum    water       Ciudades
# Topic 2      state   military   president    china       Gobierno
# Topic 3      games    yankees       teams      hit       Deportes
# Topic 4        win       play        goal    games       Deportes
# Topic 5      think       make        good     work          Otros
# Topic 6      media     people  technology   online  Empresas Tech
# Topic 7     voters    sanders  democratic  senator       Política
# Topic 8     mother     father  university     life        Familia
# Topic 9     people       time        like    years     Presidente
# Topic 10     legal      state      states   lawyer            Ley
# Topic 11     years    economy    economic     bank       Economía
# Topic 12   medical    article      public   report          Salud
# Topic 13    french    britain      france    paris         Europa
# Topic 14      city      death      killed     told        Policía
